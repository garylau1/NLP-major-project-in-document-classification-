# %%
import re
import json
import time
import boto3
import pandas as pd
from json import JSONDecoder, JSONDecodeError
from pydantic import BaseModel
import string
# ----------------------------
# 1. Configuration
# ----------------------------
DATA_PATH = 'filtered_keys_edit11 1.json'
REGION    = 'us-east-1'
MODEL_ARN = "arn:aws:bedrock:us-east-1:597571589726:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0"




# Bedrock client & model
runtime  = boto3.client("bedrock-runtime", region_name=REGION)
model_id = MODEL_ARN

# The prompt to send to Bedrock
prompt_text = """
You are a document-reading assistant. 
I will give you a block of OCR’d text from a single document. 
Parse it and respond with a single JSON object with exactly these keys at the top level (no nesting):  
- name (full name as string)  
- address (string)   
- dateOfBirth (string in DD/MM/YYYY format; if not found, "")   
- dateOfIssue (string in DD/MM/YYYY format; if not found, "") 
- dateOfExpiry (string in DD/MM/YYYY format; if not found, "")  
- licenceNumber (string; if not found, "")  
- passportNumber (string; if not found, "")  
- cardNumber (string; if not found, "")   
- identityNumber (string; if not found, "")   
- non_pii_text (array of strings):        
For each non-empty line in the OCR text:       
• Remove any numeric substrings, dates, or identifiers after the first digit or slash.        
• Trim whitespace.      
• Keep only the label portion (static text before any digit or slash).        
• Do not include empty strings in the array. If a field isn’t present in the text, set its value to an empty string. 
Return only valid JSON: a flat object with exactly those keys, no extra nesting or commentary. 

Here is one example:
"0d4068c9-c6db-435d-9ed6-c0317ecddf62-enhanced-1_pt.json": {
      "pseudo": "Learner Driver Licence New South Wales, Australia\nChung Jenkins LAMBERT\n. Card Number 2 659 265 265\n95 QMXOYCPEVJZ RD IXTZQVT NSW 2282\nLicence No 57250351 Licence Class C LRN\nDate of Birth 06 JAN 1987\nExpiry Date 03 AUG 2027",
      "ground_truth": {
        "name": "Chung Jenkins LAMBERT",
        "address": "95 QMXOYCPEVJZ RD IXTZQVT NSW 2282",
        "dateOfBirth": "06/01/1987",
        "dateOfIssue": "",
        "dateOfExpiry": "03/08/2027",
        "licenceNumber": "57250351",
        "passportNumber": "",
        "cardNumber": "2659265265",
        "identityNumber": "",
        "non_pii_text": [
          "Learner Driver Licence New South Wales, Australia",
          "Licence No",
          "Licence Class C LRN",
          "Date of Birth",
          "Expiry Date",
          "Card Number"
        ]
      }
    }

""".strip()


# ----------------------------
# 2. Pydantic model for validation
# ----------------------------
class RawDocumentInfo(BaseModel):
    name: str
    address: str
    dateOfBirth: str
    dateOfIssue: str
    dateOfExpiry: str
    licenceNumber: str
    passportNumber: str
    cardNumber: str
    identityNumber: str
    non_pii_text: list[str]

    @classmethod
    def __get_validators__(cls):
        yield from super().__get_validators__()
        yield cls._ensure_list

    @staticmethod
    def _ensure_list(v):
        return v or []

# ----------------------------
# 3. Function to parse a single OCR text block
# ----------------------------
def parse_document_text(input_text: str) -> dict:
    resp = runtime.converse(
        modelId=model_id,
        messages=[{"role": "user", "content": [{"text": prompt_text}, {"text": input_text}]}],
        inferenceConfig={"maxTokens": 512, "temperature": 0.0}
    )
    raw = resp["output"]["message"]["content"][0]["text"]

    # strip out control tokens and fences
    cleaned = re.sub(r"<\|.*?\|>", "", raw, flags=re.S)
    cleaned = re.sub(r"^```(?:json)?\s*", "", cleaned, flags=re.I)
    cleaned = re.sub(r"\s*```$", "", cleaned, flags=re.I)
    cleaned = cleaned.strip()

    # robust JSON parsing: raw_decode to ignore trailing
    decoder = JSONDecoder()
    parsed_json, end_idx = decoder.raw_decode(cleaned)
    trailing = cleaned[end_idx:].strip()
    if trailing:
        print(f"Warning: ignored trailing data: {repr(trailing[:100])}")

    if not isinstance(parsed_json, dict):
        raise ValueError(f"Expected a JSON object, got: {parsed_json!r}")

    # validate & normalize with Pydantic
    doc_info = RawDocumentInfo.parse_obj(parsed_json)
    return doc_info.dict()

# ----------------------------
# 4. Metric helper
# ----------------------------
def compute_metrics(tp: int, fp: int, fn: int):
    p = tp/(tp+fp) if tp+fp > 0 else 0.0
    r = tp/(tp+fn) if tp+fn > 0 else 0.0
    f = 2*p*r/(p+r) if p+r > 0 else 0.0
    return p, r, f


def normalize_label(label: str) -> str:
    l = label.strip()
    # remove all leading/trailing punctuation
    l = l.strip(string.punctuation)
    # collapse multiple internal spaces
    l = re.sub(r"\s+", " ", l)
    return l

# ----------------------------
# 5. Main loop: run, compare & collect metrics (including top-level key)
# ----------------------------
metrics_list = []

with open(DATA_PATH, 'r', encoding='utf-8') as f:
    data = json.load(f)

for top_level_key, files in data.items():
    for file_id, record in files.items():
        ocr_text = record.get('pseudo', '').strip()
        if not ocr_text:
            continue

        start = time.time()
        predicted = parse_document_text(ocr_text)
        latency = time.time() - start

        # PII sets (as before)
        pii_fields = {
            predicted[k].strip()
            for k in ['name','address','dateOfBirth','dateOfIssue',
                      'dateOfExpiry','licenceNumber','passportNumber',
                      'cardNumber','identityNumber']
            if predicted.get(k, "").strip().lower()
        }
        gt = record.get('ground_truth', {}) or {}
        gt_pii = {
            gt[k].strip()
            for k in ['name','address','dateOfBirth','dateOfIssue',
                      'dateOfExpiry','licenceNumber','passportNumber',
                      'cardNumber','identityNumber']
            if gt.get(k, "").strip().lower()
        }

        # --- NEW: non-PII normalization block ---
        non_pii_fields = {
            normalize_label(x)
            for x in predicted.get('non_pii_text', [])
            if x.strip()
        }
        gt_non_pii = {
            normalize_label(x)
            for x in gt.get('non_pii_text', [])
            if x.strip()
        }
        # ------------------------------------------

        # compute PII metrics
        tp_pii = len(pii_fields & gt_pii)
        fp_pii = len(pii_fields - gt_pii)
        fn_pii = len(gt_pii - pii_fields)
        p_pii, r_pii, f1_pii = compute_metrics(tp_pii, fp_pii, fn_pii)

        # compute non-PII metrics
        tp_non = len(non_pii_fields & gt_non_pii)
        fp_non = len(non_pii_fields - gt_non_pii)
        fn_non = len(gt_non_pii - non_pii_fields)
        p_non, r_non, f1_non = compute_metrics(tp_non, fp_non, fn_non)

        total_gt = len(gt_pii) + len(gt_non_pii)
        accuracy = (tp_pii + tp_non) / total_gt if total_gt > 0 else 0.0

        metrics_list.append({
            'top_level_key': top_level_key,
            'file_id': file_id,
            'latency_s': round(latency, 2),
            'p_pii': round(p_pii, 4),
            'r_pii': round(r_pii, 4),
            'f1_pii': round(f1_pii, 4),
            'p_non': round(p_non, 4),
            'r_non': round(r_non, 4),
            'f1_non': round(f1_non, 4),
            'accuracy': round(accuracy, 4),
        })

        # optional debug print
        print(f"{top_level_key} | {file_id} | tp_non={tp_non}, fp_non={fp_non}, fn_non={fn_non}")
# Out:
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 013c11b9-7bac-493a-8350-1cb8bbdaea79-1_pt.json | tp_non=4, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 01b2b7df-771a-47c4-a92c-7d8b64d75ad1-1_pt.json | tp_non=3, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 02a9909b-7795-4a6e-ba1b-cca8059af237-1_pt.json | tp_non=3, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 03cfea22-fb6e-4dae-8c1d-b969ff0d2a01-1_pt.json | tp_non=4, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 03e20df0-408a-44f7-901f-34280ba5f7dc-1_pt.json | tp_non=5, fp_non=1, fn_non=6
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 04c6ee14-f46b-44c2-bf23-4035e04bb465-enhanced-1_pt.json | tp_non=7, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 04c6ee14-f46b-44c2-bf23-4035e04bb465-raw-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 04dd75fb-b710-43c8-a6e4-cd7b48ba4f6c-1_pt.json | tp_non=7, fp_non=3, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0513d80b-1b12-4916-b444-ee767f73c285-enhanced-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0513d80b-1b12-4916-b444-ee767f73c285-raw-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 06420efc-af43-409e-9907-065c60df82c9-1_pt.json | tp_non=8, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 06549e27-f422-4a69-98a5-31dfb13ae7cb-1_pt.json | tp_non=4, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0875522c-8702-4e87-b8d8-24387b1b273b-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0bb804a6-3e12-48b8-a8df-ee4fb35657f7-1_pt.json | tp_non=5, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0d4068c9-c6db-435d-9ed6-c0317ecddf62-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0d4068c9-c6db-435d-9ed6-c0317ecddf62-raw-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 0e23c6af-44fd-4003-a2bc-27eb3da56ace-1_pt.json | tp_non=6, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 10a88bcc-b6d5-4f78-86d2-7658d8306a79-1_pt.json | tp_non=3, fp_non=3, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 124c4869-f08c-4593-99f3-dac0c8aa96b5-1_pt.json | tp_non=6, fp_non=3, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 131643fd-8a1e-4622-8868-7aed0db89745-1_pt.json | tp_non=7, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 134834c8-e9c8-4bae-b6ab-233cab239303-1_pt.json | tp_non=1, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 163420be-2047-4df6-82a2-5acddffb9fb2-enhanced-1_pt.json | tp_non=7, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 163420be-2047-4df6-82a2-5acddffb9fb2-raw-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 181707cc-e897-4fb9-bb50-85362d8a1963-enhanced-1_pt.json | tp_non=6, fp_non=7, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 181707cc-e897-4fb9-bb50-85362d8a1963-raw-1_pt.json | tp_non=5, fp_non=6, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 1ab3474a-a438-4c7b-aa05-beebc33dcd0c-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 1da2757c-19f6-4dd7-8a94-ed00f62c1484-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 1f81b2ee-e0b2-4475-b7f9-8967fb84c2f5-1_pt.json | tp_non=6, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 21361efd-74d3-4841-ac9a-ebd8169235cf-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2780af5b-c57b-4293-9eec-e9b452f75633-1_pt.json | tp_non=5, fp_non=4, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2993730a-e947-4bd5-bcb3-9f3827da1b43-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2ac42800-3e0e-4da3-888c-5802980b6167-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2ccc5592-0b33-40be-a33b-65afc1a67b71-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2dfa9cac-af42-4474-a79f-c59d137f39f3-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2dfa9cac-af42-4474-a79f-c59d137f39f3-raw-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2e03a727-3877-4edd-8abb-5a224bf76759-1_pt.json | tp_non=5, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 2e5dfd41-21ef-4ee6-8bb2-2c6c91a0b966-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 32d79bc3-09ff-4ce6-a319-4070c46c34b1-1_pt.json | tp_non=6, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 3359cc72-8073-4932-897a-afe070a12a92-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 354415fa-6589-4b73-b748-c36b3818ff0f-enhanced-1_pt.json | tp_non=4, fp_non=0, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 354415fa-6589-4b73-b748-c36b3818ff0f-raw-1_pt.json | tp_non=2, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 355ffd04-cbff-4af5-b817-2584bda5fc1f-1_pt.json | tp_non=3, fp_non=0, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 35d6a0c0-aebd-42ff-816a-dcca823be53b-1_pt.json | tp_non=5, fp_non=2, fn_non=5
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 36dd892a-f961-4643-92e3-36a8a8fe9776-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 38ab44ff-5e05-4967-8a03-02c6e8a90477-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 38b68b2f-6e97-40ef-a80b-9199bac7fcba-enhanced-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 38b68b2f-6e97-40ef-a80b-9199bac7fcba-raw-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.LEARNER.V1 | 3a4daabd-5aed-4e85-8d6b-8be7b76fc640-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 003aed02-cb59-44d2-bca9-faa27431384b-1_pt.json | tp_non=3, fp_non=1, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 005f7d61-af67-40f3-ac81-21b7dee6932c-enhanced-1_pt.json | tp_non=4, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 005f7d61-af67-40f3-ac81-21b7dee6932c-raw-1_pt.json | tp_non=4, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 00b7d83d-05d4-4ac0-b266-9d4bf64fdd7e-1_pt.json | tp_non=4, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0171ae4e-71fe-4064-9079-0b023684cfaf-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 01ab7249-c02b-48a6-81c8-76de0d5cb445-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0223791f-49a7-4c37-ae66-683bac1e970f-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 03960027-2cef-4fd5-acdb-610c63025038-1_pt.json | tp_non=4, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 075b7370-e463-4a6d-88b7-e098dc244f98-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 07fc3ea5-39d1-4117-9f2b-d72e94cf4130-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0ba720bf-2476-4de3-a4d5-40f2ccfac56a-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0dbd7352-7a2a-4509-887a-d96e988f68a3-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0df72cbf-14ac-40dd-8e71-fda5ed32969c-1_pt.json | tp_non=3, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0e396d31-fe88-4306-9e7a-fe09790d168c-1_pt.json | tp_non=4, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 0e60af7d-b1e8-452c-9c70-88d6b15beadf-1_pt.json | tp_non=4, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 10291441-20c0-4697-a917-2829e7b8daac-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 11452f07-2134-45d2-8b3e-fd2fadcd2c1b-enhanced-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 11452f07-2134-45d2-8b3e-fd2fadcd2c1b-raw-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 12867745-2281-45c6-99f5-595e950ffb5a-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 12c11492-6f5f-46ec-92f7-767eb4a1f068-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 14b58811-868e-4957-b1bc-9cfe980a5d1c-1_pt.json | tp_non=3, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 152f0b50-6b2e-4b16-b8c2-9d6c9da40b1f-enhanced-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 152f0b50-6b2e-4b16-b8c2-9d6c9da40b1f-raw-1_pt.json | tp_non=4, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 16315dcc-78bd-4c41-a073-a3477dbc1b38-enhanced-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 16315dcc-78bd-4c41-a073-a3477dbc1b38-raw-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 178cab6b-055c-4413-a295-4f2a7d0e7695-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 191af8a5-c420-421d-adfd-c0d42ac63535-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 19662f5b-2c88-45f1-9580-752e7ad948e7-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 19c4b107-5004-46bf-8461-61f644c6ddcf-1_pt.json | tp_non=2, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 1c6be8b6-09cb-4154-8745-b44e62e20b06-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 1c96274b-bfb9-437b-85f1-9fe2698916d2-1_pt.json | tp_non=4, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 1e878897-c798-45fd-a70d-fe64f8adf728-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 207efd13-47d8-41a7-98fd-957fe5fef7b4-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 20ff6663-eab5-437a-9e0f-adc7f76f9fe9-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 21fb1b16-e4e6-4193-ba34-6d8b76bdcf71-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 22d4c235-34a1-429c-a17f-64cc4aac4485-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 22ee29e2-f4dd-4ae0-9c79-472a6804c5f5-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 22f2afa0-2166-4fbb-813e-9d63edb7653e-1_pt.json | tp_non=3, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 2689be9f-5df3-46ea-80fd-167d1c8a27cc-enhanced-1_pt.json | tp_non=2, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 2689be9f-5df3-46ea-80fd-167d1c8a27cc-raw-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 28e4ede1-e412-463f-9fd9-817bdc85cfa7-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.FULL.V1 | 28f64cd8-95d1-4176-b22c-05bc2a2d782a-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 1469d265-69a8-4373-8da9-92ba01abe15d-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 1685dbce-fa35-4dd1-95ab-b48949500ffe-1_pt.json | tp_non=6, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 18afa12d-001e-4723-bb45-8ad91ff4aa2a-1_pt.json | tp_non=4, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 18f3b0ce-72a5-4ef3-86f5-05bc1e2ddcd6-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 1a72d9b9-8602-47cf-83a1-0847a6b6d4f6-1_pt.json | tp_non=3, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 1cf3cf1b-d121-422e-b2aa-bb615b29f17b-1_pt.json | tp_non=5, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 1dcbdaf7-1ca2-4a9c-8be9-16783007447c-1_pt.json | tp_non=8, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 214f15db-d9ea-4800-a112-dff91d386695-enhanced-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 214f15db-d9ea-4800-a112-dff91d386695-raw-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 21dc8f15-4d9e-4f4f-904b-fe204da41fca-1_pt.json | tp_non=9, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 245e078d-0904-4cea-b568-cf1232da9fe6-1_pt.json | tp_non=7, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 252a992c-5d9d-497e-ba5f-6ea5413dcacc-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 252a992c-5d9d-497e-ba5f-6ea5413dcacc-raw-1_pt.json | tp_non=6, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 257440f9-f726-4c39-ab03-e89ad73853e0-1_pt.json | tp_non=5, fp_non=5, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 278f68d3-e8de-417a-bfc4-58cd579d2d78-1_pt.json | tp_non=5, fp_non=1, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 27c07e34-747c-49e5-b58b-036c99d054f4-1_pt.json | tp_non=6, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 27d0bd2e-764a-4608-83f5-5382ea13b73f-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2819dd87-47b0-4e02-98fc-e87df580bca5-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2819dd87-47b0-4e02-98fc-e87df580bca5-raw-1_pt.json | tp_non=5, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 29481b95-49b4-4327-bb66-6726596a1b7b-1_pt.json | tp_non=5, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2e42f97c-8a4b-4f65-a0a5-7c22ac463878-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2e42f97c-8a4b-4f65-a0a5-7c22ac463878-raw-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2e563f36-d2be-45e4-9404-525d3f2ce35f-1_pt.json | tp_non=7, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2f0e5a45-c92f-43b7-9160-eae208c8f78b-enhanced-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 2f0e5a45-c92f-43b7-9160-eae208c8f78b-raw-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 311f8397-a10f-4a3c-8b18-3a5030fd573d-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 311f8397-a10f-4a3c-8b18-3a5030fd573d-raw-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 3146f1ba-8197-4296-8af7-54e2531b8625-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 3146f1ba-8197-4296-8af7-54e2531b8625-raw-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 3155ed34-7a1a-4da2-86b2-b25d41867ddd-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 33359e47-7999-4013-bad3-350218f7ba04-enhanced-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 33359e47-7999-4013-bad3-350218f7ba04-raw-1_pt.json | tp_non=8, fp_non=3, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 34595b9f-65ee-47d7-9cff-21e2eb21a1fd-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 345a4124-f788-41b4-a858-22be18c8db5e-enhanced-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 345a4124-f788-41b4-a858-22be18c8db5e-raw-1_pt.json | tp_non=6, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.HEAVY.V1 | 346ed860-5e7b-45ad-9c13-2fc46e0ba847-1_pt.json | tp_non=5, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 0dc4a9d6-98fc-423a-9824-73c8ec6feb7e-1_pt.json | tp_non=8, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 0dcc710e-6aeb-4b7a-b2dc-2fbc5f91c53c-1_pt.json | tp_non=5, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 0e030303-dc1f-44f6-9ee4-8807580e1593-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 0f1a4702-a147-4be6-a2cd-045dd56159e0-1_pt.json | tp_non=4, fp_non=3, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 0f356f47-b7b1-457b-b240-cb05c203bd4b-1_pt.json | tp_non=6, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 133f1c3b-3a3e-4b0a-b489-49242f0117da-1_pt.json | tp_non=5, fp_non=4, fn_non=6
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 13c7033c-d3d0-4ab8-89ce-803ca4fd4e8e-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 15ed1b82-cb46-4144-b42b-1243b01bc991-1_pt.json | tp_non=7, fp_non=3, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 163da673-6f60-4fb9-8ca4-cb77ed9a5f13-1_pt.json | tp_non=7, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 16961b9b-6b0a-45cd-b2cf-25439922a1f5-1_pt.json | tp_non=7, fp_non=3, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1971d843-173b-4705-9540-53ec523e6d1e-1_pt.json | tp_non=4, fp_non=5, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1ba56ef8-b5ac-4fba-b053-d5c8574d4e15-1_pt.json | tp_non=6, fp_non=4, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1bbe873f-b879-4708-a5e2-78eb9e2bf23b-1_pt.json | tp_non=7, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1cc87b70-37db-4a23-a3ed-d6faac24a24c-1_pt.json | tp_non=5, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1d8e30f1-ab94-4330-8dba-20cad1b0a72c-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1dcd292c-81f2-432a-83be-07a618a63ef8-1_pt.json | tp_non=4, fp_non=4, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 1f9419e9-d147-45d4-a772-5001b7abbd34-1_pt.json | tp_non=5, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 20652f53-25dc-41ee-ae10-cbacb7ca0f2b-enhanced-1_pt.json | tp_non=6, fp_non=5, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 20652f53-25dc-41ee-ae10-cbacb7ca0f2b-raw-1_pt.json | tp_non=6, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 230c4191-78a4-41a2-a5ed-76a0d57b7f9c-1_pt.json | tp_non=5, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 24f62b00-bde3-4e22-af33-c3f54b8f3810-1_pt.json | tp_non=3, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 28bf91fc-bf19-4d99-9ec8-599328e8ac8a-1_pt.json | tp_non=4, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 2a71ac94-adcd-4480-995a-fa0b1ddffbbe-1_pt.json | tp_non=4, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 2a8f77ca-5d2a-42ec-b7f3-c3c251a8541f-1_pt.json | tp_non=4, fp_non=3, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 2a9e20e3-dc32-4218-9241-72d294fb8611-1_pt.json | tp_non=8, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 2c60c0db-6b4e-4d58-b851-11b27fa8ac99-1_pt.json | tp_non=6, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 2f4e58c6-fda2-4626-ad9b-4c40fddb6e7b-1_pt.json | tp_non=7, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 367cddbe-ce90-48f0-8d5c-a7e723aeccc3-1_pt.json | tp_non=5, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 36da8c2d-6d52-472f-8c47-67f597e56a6a-1_pt.json | tp_non=3, fp_non=6, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 3742d1a4-a767-441f-b6eb-eb3ad246b53b-1_pt.json | tp_non=3, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 374df831-f91a-4e9a-9bd0-a8c68b60b9f4-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 379ca1d6-29f2-4a18-94c5-1db63cffc93d-1_pt.json | tp_non=7, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 384ce44a-1ffa-458d-bcb9-7dd232447043-1_pt.json | tp_non=7, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 38b8c8ff-9190-4da6-b4b9-c3b4c28e7835-1_pt.json | tp_non=7, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 392c9efb-d9b6-4b6f-aff9-24b63f4491d3-1_pt.json | tp_non=6, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1 | 3a7c3ba2-cf76-46ae-b9b5-c7adc581896d-1_pt.json | tp_non=4, fp_non=6, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 02ce7ba8-8826-47e6-9c6a-c24bb4405704-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 06111381-cc41-4540-af2a-adc28a7345e9-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 0fa2bddc-09ca-4b51-85f8-a8adbd110f28-1_pt.json | tp_non=2, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 13ce1279-a18e-44ac-b7a0-f34ff4980448-1_pt.json | tp_non=4, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 1ae93fe9-9f18-4015-b071-14d5eb651bc1-enhanced-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 1ae93fe9-9f18-4015-b071-14d5eb651bc1-raw-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 2e7b3c79-78dc-4817-85c4-d54a93c6dd17-1_pt.json | tp_non=3, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 36650d0e-de74-493d-8e8a-b02fa16eab5c-1_pt.json | tp_non=4, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 3b9e9e99-7ad1-4a1a-b617-88da614c0b57-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 3c2f479f-956b-4101-9e65-792969336896-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 43ebc399-bad9-4d3b-b533-43cda6157ae4-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 49947aea-d9ac-4eb6-bf80-2fc93c6ad42d-1_pt.json | tp_non=6, fp_non=0, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 4acb5cf3-d777-4bec-a4ba-8fd9fc58fa6d-1_pt.json | tp_non=4, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 4e7fd719-72b7-496d-be72-e71dd86cd787-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 5267bbb5-ee68-4090-89e8-bc655e4dcca9-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 5f459fc5-5cb8-41c7-9de3-cbc13eabfd53-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 9d94c7fa-3ef0-4f1c-b9bd-efdb7a5a773e-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | 9f20ee89-6aa8-4b92-844d-ba6112c8c7b8-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | ad13364a-1dc8-4ae0-9aef-e939e4a3b1fa-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | b59580b2-1af8-40ab-afb6-b09b1812482e-1_pt.json | tp_non=3, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | b8602129-b576-496a-8f49-c29fd70f27c3-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | c938441b-6635-4eb9-8bfb-66d2f9e38ecf-1_pt.json | tp_non=5, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.HEAVY.V1 | f76bc5a9-694a-404c-9776-c871264f4cb1-1_pt.json | tp_non=5, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a38f2bd-ebba-4cdf-b186-ba4e14749ca5-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a54fe7d-6594-47c3-8b7a-c0dcd11ec3d5-1_pt.json | tp_non=5, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a6ecedf-2028-4925-a633-2e9dd256944d-1_pt.json | tp_non=4, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a71fbcf-3d6f-4dc2-b52a-74e7f68c0a2d-1_pt.json | tp_non=6, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a7365fc-72f0-49d5-ae85-e2286281e0e5-1_pt.json | tp_non=8, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a852a09-6980-472b-8133-8daf65874565-1_pt.json | tp_non=5, fp_non=6, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a86bd92-ff1c-49cc-b15e-73e7ebc983cc-1_pt.json | tp_non=4, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a89194a-a833-4c3c-8230-0ed5ba1b3771-1_pt.json | tp_non=7, fp_non=4, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a8a0a72-e512-4584-8025-489d4fa7df31-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a8b70a4-5365-40f2-b17f-0ecf627013c4-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0a9d2863-b160-43b1-a088-f42865116e6c-1_pt.json | tp_non=2, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0ac0bf44-d9c9-4316-8866-32b8f47d2e83-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0af2d27b-0ff7-4c4b-9a51-1bf34c967ae9-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0af8ad0a-5f29-46b8-9b8f-dfbd963bada6-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0afdd128-c47b-487c-96ca-47a79c37b044-enhanced-1_pt.json | tp_non=6, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0afdd128-c47b-487c-96ca-47a79c37b044-raw-1_pt.json | tp_non=5, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0b492ce3-2032-45a6-8e7b-230cac7fe710-1_pt.json | tp_non=4, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0b5f3133-9f88-421a-940f-c559f8ad22f7-1_pt.json | tp_non=6, fp_non=2, fn_non=4
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0b660dcf-dbfe-46f1-90c7-6212502c7880-1_pt.json | tp_non=3, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0b815374-d1af-453c-a0dc-9dace08cfdb8-1_pt.json | tp_non=4, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0b87787a-5f19-4a07-b4f0-1aa30440179e-1_pt.json | tp_non=6, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.NSW.FULL.V1 | 0ba185ff-d98a-47ae-9ea1-c653e8b7c8c4-1_pt.json | tp_non=4, fp_non=4, fn_non=1
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 00ebc525-23b7-408c-859c-0e3b830cea32-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 018ea5bd-7c9d-49ff-947f-9e8c59a6fe28-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 01a730e6-ea9f-4337-a0c3-d3deb2d0ed1b-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 01f9076e-bb52-4b8e-ba91-e358e81c8139-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 02b48551-4369-4906-b7c4-117b96f7fcd3-1_pt.json | tp_non=8, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 03238e58-7a62-467b-868c-00c83d61a76a-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 033760ae-54e6-4067-a859-60707401f0d2-enhanced-1_pt.json | tp_non=7, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 033760ae-54e6-4067-a859-60707401f0d2-raw-1_pt.json | tp_non=6, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 034b316b-9e4b-4f17-a76b-67d696780547-1_pt.json | tp_non=4, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 036950f4-d0a2-4efc-971e-07ba5db69b2e-1_pt.json | tp_non=2, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 043fcb31-5384-4b24-9db0-9643b6279f70-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 04656045-2aea-4ef3-af88-e1a1e353fb16-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 08edb258-8158-4048-9877-ddf5efc302d5-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 0904a6d5-f12d-4056-972f-38b15c1437ce-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 09a64900-ef47-40c8-9314-7932f9436960-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | 09bd5fe4-c0aa-4687-8b3b-879d168f88db-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | debug-for-mike8-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | debug-for-mikerf3-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | download1-1_pt.json | tp_non=7, fp_non=3, fn_non=0
# DRIVERS_LICENCE.AUS.SA.FULL.V1 | MikeSA-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 006f3a67-087c-4952-9c70-ca5405f6fb00-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0239b068-a019-4860-8808-c20b29ff3424-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 04ace45d-0852-4175-9828-d12231f6fae8-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 06f7d215-a8c0-4afa-a874-6f23b78eabda-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 092a522f-bfd5-4a77-8ad3-cdd7d86852a5-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 098acf63-d1aa-40d6-bd8f-96c6029c972c-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 099fefe0-fcc1-490d-a840-3dd5dd44d77b-enhanced-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 099fefe0-fcc1-490d-a840-3dd5dd44d77b-raw-1_pt.json | tp_non=3, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 09dc41f4-1911-4d67-aea2-b29aef2b5c62-1_pt.json | tp_non=5, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0a141a5c-b894-43c0-9bb4-baaabcb9626f-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0abe6a04-d182-4688-931e-c98e05f5ab8b-1_pt.json | tp_non=5, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0b2ecffb-49e2-4006-b177-451ecef800c1-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0da766f6-9ded-4d5c-8f4a-82b7e2c90693-1_pt.json | tp_non=6, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0e3a12e9-3f43-407c-a08a-81186857f054-enhanced-1_pt.json | tp_non=8, fp_non=0, fn_non=3
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | 0e3a12e9-3f43-407c-a08a-81186857f054-raw-1_pt.json | tp_non=9, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.HEAVY.V1 | debug-for-mike6-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 006b9d1a-b86c-423e-8cdf-1cf3c8f9f8aa-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 01a23521-620f-49f3-832a-1da8437d8b84-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 01c3cfdb-945f-430a-9356-2db6a5811316-1_pt.json | tp_non=8, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 02cb99d2-9ecd-4d7b-9e5d-7d3a8f53e1e1-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 03e4ba26-fae7-4395-b98c-4c6ab2c4d93d-enhanced-1_pt.json | tp_non=6, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 03e4ba26-fae7-4395-b98c-4c6ab2c4d93d-raw-1_pt.json | tp_non=8, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 03f7c876-09ab-46fc-9aae-d4b75080a860-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 05a846ed-80dd-4c6e-ac6d-d75fee6ce6fb-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 067dcdb7-82f7-4bf4-901e-7f3985871d3e-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 093a4b20-453d-4ac8-a8ae-c868b6563e2e-1_pt.json | tp_non=7, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 0980ebb3-3457-4233-8471-47c5818da48e-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 0c8cc87d-829a-4967-940b-2f6f2bfa226e-1_pt.json | tp_non=7, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 0d47c4fc-adfd-4fb7-8cad-a59364b8c6b8-1_pt.json | tp_non=6, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 0d7ee7bd-246a-45ef-b950-aa597f451433-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1 | 0e9e39c5-c3c8-4d1a-b0dc-3731555c774b-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 00f1beec-d05b-448b-be80-d46dcfa59556-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 0b990e80-8fc6-4d3b-ae4d-8082315a932b-1_pt.json | tp_non=4, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 0ff01a42-b901-4f18-b3ce-d123bb6081f7-1_pt.json | tp_non=6, fp_non=0, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 29d128b2-d189-4f28-8efa-8ca10f07c47d-1_pt.json | tp_non=3, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 2b4ddafe-38bb-491f-8e5a-2e6ee77b4671-1_pt.json | tp_non=2, fp_non=1, fn_non=5
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 3b81078d-5be0-42bf-aef7-6014697b3f8d-1_pt.json | tp_non=4, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 3c508255-0474-42a2-b2d2-832fc591cc71-1_pt.json | tp_non=4, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 3d584ea5-39cb-4b7e-abd2-4b24441ae7b1-enhanced-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 3d584ea5-39cb-4b7e-abd2-4b24441ae7b1-raw-1_pt.json | tp_non=4, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 3d7b6269-c981-4e2f-ab1f-f2f7a5d9433f-1_pt.json | tp_non=5, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 4d75979f-cf6b-43c3-8d1e-7f02760adfb0-1_pt.json | tp_non=6, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 4e3d47cc-07c1-4f36-9d31-bd50aa0ed376-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 58aea720-5419-4cdb-9125-a4945ef2b7cb-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 6fb7bbec-8b18-46fa-9f71-936e9c6d0676-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 7a3360bb-b4e8-4235-8fd5-d808f7d0f802-1_pt.json | tp_non=3, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 9a05be9c-97d6-4fbf-a2a4-229c4aaf3fbf-1_pt.json | tp_non=4, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.TAS.LEARNER.V1 | 9c2df537-f546-498b-b60b-592864b1bb83-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 000b9f1f-a43c-43ba-aa91-80275d36b098-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 001742b8-cc1d-4557-ac50-5ab77b176c20-raw-1_pt.json | tp_non=5, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 001be905-186a-4521-be0d-b4093e9123a1-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 002c548e-81e2-4136-b4b9-af1cfa06c926-1_pt.json | tp_non=5, fp_non=2, fn_non=2
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 008c3645-c47a-4f2f-b1dc-8b418699690b-enhanced-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 008c3645-c47a-4f2f-b1dc-8b418699690b-raw-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00913097-4add-4bb7-80ed-7486f7249965-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 0095c985-80eb-4077-a38c-75afe7dde590-1_pt.json | tp_non=3, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00d6d92f-1eb3-479d-9446-fe7f72482efb-1_pt.json | tp_non=5, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00dcbc88-6c85-4694-8938-9fa61a167168-enhanced-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00dcbc88-6c85-4694-8938-9fa61a167168-raw-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00e44363-65ac-4197-a44d-95c0e8fd329f-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 00ebbb41-16b4-4267-8460-e0aa542abe9b-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 01008b7a-de79-46d6-80a0-db80f528fb81-1_pt.json | tp_non=7, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 011e29f8-5d76-45b2-8b1e-b579072380c2-enhanced-1_pt.json | tp_non=7, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.VIC.FULL.V1 | 011e29f8-5d76-45b2-8b1e-b579072380c2-raw-1_pt.json | tp_non=5, fp_non=4, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 029a07ec-1479-4b15-a5cd-f42b28cb0ca5-1_pt.json | tp_non=8, fp_non=3, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 08d76665-be9e-4eb5-bde0-ed39accb3f78-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 0baea607-721a-4299-9b60-b02bb1f5d312-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 0c585359-ccf4-4bd6-a97d-0e86b9cdad6e-1_pt.json | tp_non=8, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 1828d49d-ee56-4bd8-918e-c819c93405de-1_pt.json | tp_non=5, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 1df95fca-17ff-4e24-9077-dbe59e2867c4-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 23b195f1-68de-4036-b01c-5dca06935aee-1_pt.json | tp_non=8, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 2f9736be-d728-4077-85e7-e45fd10b22ff-1_pt.json | tp_non=8, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 30ac47ef-e539-4b8d-a056-8eb6da6bea0c-1_pt.json | tp_non=7, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 30dec43f-1bba-4e8c-8af3-4ab205bceff9-1_pt.json | tp_non=8, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 3730c10b-88c3-4043-8207-fc805e8d0b11-1_pt.json | tp_non=7, fp_non=2, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 3bfe9c6c-78b3-4603-8b4b-ac0d7cfee1f9-1_pt.json | tp_non=9, fp_non=0, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 41e627a5-3e6d-4fdb-9eff-ffca7e80ed00-1_pt.json | tp_non=6, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1 | 46ca2cb2-3b0d-426b-bbf3-cd55cda965e4-1_pt.json | tp_non=7, fp_non=2, fn_non=3
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 008d12c1-6643-4434-9ee6-3964cc410b12-1_pt.json | tp_non=6, fp_non=2, fn_non=0
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 00bc089c-1419-49ca-9840-cb2899e08e2b-1_pt.json | tp_non=7, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 00f8ca56-64ae-46ef-81ca-beb2d4164958-1_pt.json | tp_non=3, fp_non=6, fn_non=2
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 014a3636-15bc-4f89-b910-9fe5050b6c6e-1_pt.json | tp_non=9, fp_non=0, fn_non=0
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 018926ac-e0fa-47cf-92d0-5c2d96683ad8-1_pt.json | tp_non=7, fp_non=1, fn_non=2
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 01c9f1cb-91c0-40ac-a8ba-5def7dcfc94e-1_pt.json | tp_non=8, fp_non=3, fn_non=0
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 01f068cd-4a1f-4f76-964b-70a1993b61fa-1_pt.json | tp_non=4, fp_non=4, fn_non=2
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 023ac429-1950-4369-a2d9-8fdb9fa47e37-1_pt.json | tp_non=8, fp_non=1, fn_non=0
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 0295a551-5921-4755-83cd-2f43d8b013cc-1_pt.json | tp_non=6, fp_non=3, fn_non=3
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 02a13f57-d51f-4c70-9d9a-927a851b2b2b-1_pt.json | tp_non=7, fp_non=3, fn_non=2
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 02c35531-59c0-4a53-a02f-4de8dce36117-1_pt.json | tp_non=6, fp_non=4, fn_non=3
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | 02d3808e-5f54-453b-afb0-5cb5a52d8e0e-1_pt.json | tp_non=6, fp_non=3, fn_non=4
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | debug-mirza-1_pt.json | tp_non=5, fp_non=1, fn_non=1
# DRIVERS_LICENCE.AUS.QLD.FULL.V1 | fa572e8f-6323-4535-90ca-d1953b2cffb9-raw-1_pt.json | tp_non=5, fp_non=2, fn_non=1

# %%
# ----------------------------
# 6. At end: show summary table
# ----------------------------
df = pd.DataFrame(metrics_list)


# Assuming you’ve already done:
# import pandas as pd
# df = pd.DataFrame(metrics_list)

# Add a new column “f1_combined” that combines f1_pii and f1_non.
# Here we take the harmonic mean (the usual F1 combination) of the two:
df['f1_combined'] = 2 * df['f1_pii'] * df['f1_non'] / (df['f1_pii'] + df['f1_non'])

# If you prefer a simple average instead, you could do:
# df['f1_combined'] = (df['f1_pii'] + df['f1_non']) / 2

# Inspect the first few rows


# optionally: save to CSV
df.to_csv('latest_metrics_summary_claude.csv', index=False)

# %%
# 3. Calculate average of each numeric column
numeric_cols = ['latency_s', 'p_pii', 'r_pii', 'f1_pii', 'p_non', 'r_non', 'f1_non', 'accuracy']
averages = df[numeric_cols].mean().to_frame(name='average').T

print("=== Average Metrics ===")
print(averages)
# Out:
# === Average Metrics ===
#          latency_s     p_pii    r_pii    f1_pii     p_non     r_non    f1_non  \
# average   4.844295  0.908783  0.90812  0.907528  0.822638  0.840939  0.825336
#
#          accuracy
# average  0.871508

# %%
import pandas as pd



# Group by top-level key and compute mean of f1_pii, f1_non, and accuracy
grouped = (
    df
    .groupby('top_level_key')[['f1_pii', 'f1_non', 'accuracy',"f1_combined"]]
    .mean()
    .reset_index()
)

# Show the result
print("=== Mean f1_pii, f1_non, accuracy by top_level_key ===")
print(grouped)
# Out:
# === Mean f1_pii, f1_non, accuracy by top_level_key ===
#                              top_level_key    f1_pii    f1_non  accuracy  \
# 0          DRIVERS_LICENCE.AUS.NSW.FULL.V1  0.840882  0.792505  0.834800
# 1         DRIVERS_LICENCE.AUS.NSW.HEAVY.V1  0.935172  0.890972  0.921406
# 2       DRIVERS_LICENCE.AUS.NSW.LEARNER.V1  0.921663  0.765915  0.836875
# 3   DRIVERS_LICENCE.AUS.NSW.PROVISIONAL.V1  0.833303  0.681811  0.774564
# 4          DRIVERS_LICENCE.AUS.QLD.FULL.V1  0.696393  0.761886  0.740800
# 5           DRIVERS_LICENCE.AUS.SA.FULL.V1  0.955455  0.942565  0.953120
# 6    DRIVERS_LICENCE.AUS.SA.PROVISIONAL.V1  0.950650  0.871686  0.912064
# 7          DRIVERS_LICENCE.AUS.TAS.FULL.V1  0.951855  0.847664  0.906588
# 8         DRIVERS_LICENCE.AUS.TAS.HEAVY.V1  0.936365  0.852922  0.890952
# 9       DRIVERS_LICENCE.AUS.TAS.LEARNER.V1  0.860218  0.763547  0.818382
# 10         DRIVERS_LICENCE.AUS.VIC.FULL.V1  0.952275  0.876188  0.921969
# 11        DRIVERS_LICENCE.AUS.VIC.HEAVY.V1  0.934694  0.920569  0.921531
# 12  DRIVERS_LICENCE.AUS.VIC.PROVISIONAL.V1  0.973333  0.919613  0.949400
#
#     f1_combined
# 0      0.809956
# 1      0.904742
# 2      0.827248
# 3      0.743381
# 4      0.716485
# 5      0.943897
# 6      0.905347
# 7      0.885270
# 8      0.881082
# 9      0.801332
# 10     0.905101
# 11     0.919600
# 12     0.943181

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by the top‐level key and average the four metrics
grouped = df.groupby('top_level_key')[['f1_pii','f1_non','accuracy','f1_combined']].mean()

# Plot
ax = grouped.plot(kind='bar', figsize=(12,7))
ax.set_title('Average f1_pii, f1_non, accuracy, and f1_combined by Top-Level Key')
ax.set_xlabel('Top-Level Key')
ax.set_ylabel('Mean Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
